# %%
# !pip3 install streamlit
# !pip3 install mysql.connector
# !pip3 install plotly
# !pip3 install os
# !pip3 install gitpython
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# ...

# %%
# !git clone https://github.com/PhonePe/pulse.git
# Out:
# fatal: destination path 'pulse' already exists and is not an empty directory.

# %%
import pandas as pd
import os 
import json
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import nbformat

# %%
path1="/Users/karthikeyank/Documents/phonepe/pulse/data/aggregated/transaction/country/india/state/"
agg_trans_list = os.listdir(path1)

columns1 = {'State': [], 'Year': [], 'Quarter': [], 'Transaction_type': [], 'Transaction_count': [],
            'Transaction_amount': []}
for state in agg_trans_list:
    cur_state = path1 + state + "/"
    agg_year_list = os.listdir(cur_state)
    
    for year in agg_year_list:
        cur_year = cur_state + year + "/"
        agg_file_list = os.listdir(cur_year)
        
        for file in agg_file_list:
            cur_file = cur_year + file
            data = open(cur_file, 'r')
            A = json.load(data)
            
            for i in A['data']['transactionData']:
                name = i['name']
                count = i['paymentInstruments'][0]['count']
                amount = i['paymentInstruments'][0]['amount']
                columns1['Transaction_type'].append(name)
                columns1['Transaction_count'].append(count)
                columns1['Transaction_amount'].append(amount)
                columns1['State'].append(state)
                columns1['Year'].append(year)
                columns1['Quarter'].append(int(file.strip('.json')))
                
df_agg_trans = pd.DataFrame(columns1)
df_agg_trans.to_csv("agg_trans.csv")
df_agg_trans
# Out:
#                           State  Year  Quarter          Transaction_type  \
# 0     andaman-&-nicobar-islands  2022        1     Peer-to-peer payments
# 1     andaman-&-nicobar-islands  2022        1         Merchant payments
# 2     andaman-&-nicobar-islands  2022        1  Recharge & bill payments
# 3     andaman-&-nicobar-islands  2022        1        Financial Services
# 4     andaman-&-nicobar-islands  2022        1                    Others
# ...                         ...   ...      ...                       ...
# 3949                   nagaland  2018        4  Recharge & bill payments
# 3950                   nagaland  2018        4     Peer-to-peer payments
# 3951                   nagaland  2018        4         Merchant payments
# 3952                   nagaland  2018        4        Financial Services
# 3953                   nagaland  2018        4                    Others
#
#       Transaction_count  Transaction_amount
# 0                342649        1.682329e+09
# ...

# %%
path2 = "/Users/karthikeyank/Documents/phonepe/pulse/data/aggregated/user/country/india/state/"

agg_user_list = os.listdir(path2)

columns2 = {'State': [], 'Year': [], 'Quarter': [], 'Brands': [], 'Count': [],
            'Percentage': []}
for state in agg_user_list:
    cur_state = path2 + state + "/"
    agg_year_list = os.listdir(cur_state)
    
    for year in agg_year_list:
        cur_year = cur_state + year + "/"
        agg_file_list = os.listdir(cur_year)

        for file in agg_file_list:
            cur_file = cur_year + file
            data = open(cur_file, 'r')
            B = json.load(data)
            try:
                for i in B["data"]["usersByDevice"]:
                    brand_name = i["brand"]
                    counts = i["count"]
                    percents = i["percentage"]
                    columns2["Brands"].append(brand_name)
                    columns2["Count"].append(counts)
                    columns2["Percentage"].append(percents)
                    columns2["State"].append(state)
                    columns2["Year"].append(year)
                    columns2["Quarter"].append(int(file.strip('.json')))
            except:
                pass
df_agg_user = pd.DataFrame(columns2)
df_agg_user.to_csv("agg_user.csv", index=False)
df_agg_user
# Out:
#                           State  Year  Quarter   Brands  Count  Percentage
# 0     andaman-&-nicobar-islands  2022        1     Vivo  18688    0.244966
# 1     andaman-&-nicobar-islands  2022        1   Xiaomi  17957    0.235384
# 2     andaman-&-nicobar-islands  2022        1  Samsung  12955    0.169817
# 3     andaman-&-nicobar-islands  2022        1   Realme   6769    0.088730
# 4     andaman-&-nicobar-islands  2022        1     Oppo   6461    0.084692
# ...                         ...   ...      ...      ...    ...         ...
# 6727                   nagaland  2018        4    Apple   1148    0.026700
# 6728                   nagaland  2018        4   Lenovo   1024    0.023816
# 6729                   nagaland  2018        4   Huawei    849    0.019746
# 6730                   nagaland  2018        4     Asus    840    0.019536
# 6731                   nagaland  2018        4   Others   6249    0.145336
#
# [6732 rows x 6 columns]

# %%
path3 = "/Users/karthikeyank/Documents/phonepe/pulse/data/map/transaction/hover/country/india/state/"

map_trans_list = os.listdir(path3)

columns3 = {'State': [], 'Year': [], 'Quarter': [], 'District': [], 'Count': [],
            'Amount': []}

for state in map_trans_list:
    cur_state = path3 + state + "/"
    map_year_list = os.listdir(cur_state)
    
    for year in map_year_list:
        cur_year = cur_state + year + "/"
        map_file_list = os.listdir(cur_year)
        
        for file in map_file_list:
            cur_file = cur_year + file
            data = open(cur_file, 'r')
            C = json.load(data)
            
            for i in C["data"]["hoverDataList"]:
                district = i["name"]
                count = i["metric"][0]["count"]
                amount = i["metric"][0]["amount"]
                columns3["District"].append(district)
                columns3["Count"].append(count)
                columns3["Amount"].append(amount)
                columns3['State'].append(state)
                columns3['Year'].append(year)
                columns3['Quarter'].append(int(file.strip('.json')))
                
df_map_trans = pd.DataFrame(columns3)
df_map_trans.to_csv("map_trans.csv", index=False)
df_map_trans
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2022        1
# 1      andaman-&-nicobar-islands  2022        1
# 2      andaman-&-nicobar-islands  2022        1
# 3      andaman-&-nicobar-islands  2022        2
# 4      andaman-&-nicobar-islands  2022        2
# ...                          ...   ...      ...
# 16095                   nagaland  2018        4
# 16096                   nagaland  2018        4
# 16097                   nagaland  2018        4
# 16098                   nagaland  2018        4
# 16099                   nagaland  2018        4
#
#                                 District   Count        Amount
# 0      north and middle andaman district   60059  1.616249e+08
# 1                 south andaman district  705512  1.872991e+09
# 2                      nicobars district   29177  9.441413e+07
# 3      north and middle andaman district   72573  1.956932e+08
# 4                 south andaman district  954875  2.357327e+09
# ...

# %%
# Data frame of map user
path4 = "/Users/karthikeyank/Documents/phonepe/pulse/data/map/user/hover/country/india/state/"

map_user_list = os.listdir(path4)

columns4 = {"State": [], "Year": [], "Quarter": [], "District": [],
            "RegisteredUser": [], "AppOpens": []}

for state in map_user_list:
    cur_state = path4 + state + "/"
    map_year_list = os.listdir(cur_state)
    
    for year in map_year_list:
        cur_year = cur_state + year + "/"
        map_file_list = os.listdir(cur_year)
        
        for file in map_file_list:
            cur_file = cur_year + file
            data = open(cur_file, 'r')
            D = json.load(data)
            
            for i in D["data"]["hoverData"].items():
                district = i[0]
                registereduser = i[1]["registeredUsers"]
                appOpens = i[1]['appOpens']
                columns4["District"].append(district)
                columns4["RegisteredUser"].append(registereduser)
                columns4["AppOpens"].append(appOpens)
                columns4['State'].append(state)
                columns4['Year'].append(year)
                columns4['Quarter'].append(int(file.strip('.json')))
                
df_map_user = pd.DataFrame(columns4)
df_map_user.to_csv("map_user.csv", index=False)
df_map_user
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2022        1
# 1      andaman-&-nicobar-islands  2022        1
# 2      andaman-&-nicobar-islands  2022        1
# 3      andaman-&-nicobar-islands  2022        2
# 4      andaman-&-nicobar-islands  2022        2
# ...                          ...   ...      ...
# 16099                   nagaland  2018        4
# 16100                   nagaland  2018        4
# 16101                   nagaland  2018        4
# 16102                   nagaland  2018        4
# 16103                   nagaland  2018        4
#
#                                 District  RegisteredUser  AppOpens
# 0      north and middle andaman district           10720    904869
# 1                 south andaman district           63487   2368756
# 2                      nicobars district            2081    573782
# 3      north and middle andaman district           11379    963824
# ...

# %%
# Data frame of top transactions
path5 = "/Users/karthikeyank/Documents/phonepe/pulse/data/top/transaction/country/india/state/"

top_trans_list = os.listdir(path5)
columns5 = {'State': [], 'Year': [], 'Quarter': [], 'Pincode': [], 'Transaction_count': [],
            'Transaction_amount': []}

for state in top_trans_list:
    cur_state = path5 + state + "/"
    top_year_list = os.listdir(cur_state)
    
    for year in top_year_list:
        cur_year = cur_state + year + "/"
        top_file_list = os.listdir(cur_year)
        
        for file in top_file_list:
            cur_file = cur_year + file
            data = open(cur_file, 'r')
            E = json.load(data)
            
            for i in E['data']['pincodes']:
                name = i['entityName']
                count = i['metric']['count']
                amount = i['metric']['amount']
                columns5['Pincode'].append(name)
                columns5['Transaction_count'].append(count)
                columns5['Transaction_amount'].append(amount)
                columns5['State'].append(state)
                columns5['Year'].append(year)
                columns5['Quarter'].append(int(file.strip('.json')))
df_top_trans = pd.DataFrame(columns5)
df_top_trans.to_csv("top_trans.csv", index=False)
df_top_trans
# Out:
#                           State  Year  Quarter Pincode  Transaction_count  \
# 0     andaman-&-nicobar-islands  2022        1  744101             209941
# 1     andaman-&-nicobar-islands  2022        1  744103             157230
# 2     andaman-&-nicobar-islands  2022        1  744105             122716
# 3     andaman-&-nicobar-islands  2022        1  744102              74883
# 4     andaman-&-nicobar-islands  2022        1  744104              32471
# ...                         ...   ...      ...     ...                ...
# 7848                   nagaland  2018        4  797113               5861
# 7849                   nagaland  2018        4  798601               5806
# 7850                   nagaland  2018        4  797117               4640
# 7851                   nagaland  2018        4  797118               4531
# 7852                   nagaland  2018        4  797116               4309
#
#       Transaction_amount
# 0           6.159781e+08
# 1           3.997160e+08
# ...

# %%
# Data frame of top users
path6 = "/Users/karthikeyank/Documents/phonepe/pulse/data/top/user/country/india/state/"
top_user_list = os.listdir(path6)
columns6 = {'State': [], 'Year': [], 'Quarter': [], 'Pincode': [],
            'RegisteredUsers': []}

for state in top_user_list:
    cur_state = path6 + state + "/"
    top_year_list = os.listdir(cur_state)
    
    for year in top_year_list:
        cur_year = cur_state + year + "/"
        top_file_list = os.listdir(cur_year)
        
        for file in top_file_list:
            cur_file = cur_year + file
            data = open(cur_file, 'r')
            F = json.load(data)
            
            for i in F['data']['pincodes']:
                name = i['name']
                registeredUsers = i['registeredUsers']
                columns6['Pincode'].append(name)
                columns6['RegisteredUsers'].append(registeredUsers)
                columns6['State'].append(state)
                columns6['Year'].append(year)
                columns6['Quarter'].append(int(file.strip('.json')))
df_top_user = pd.DataFrame(columns6)
df_top_user.to_csv("top_user.csv", index=False)
df_top_user
# Out:
#                           State  Year  Quarter Pincode  RegisteredUsers
# 0     andaman-&-nicobar-islands  2022        1  744103            15011
# 1     andaman-&-nicobar-islands  2022        1  744105            13070
# 2     andaman-&-nicobar-islands  2022        1  744101            12300
# 3     andaman-&-nicobar-islands  2022        1  744102             8271
# 4     andaman-&-nicobar-islands  2022        1  744202             4107
# ...                         ...   ...      ...     ...              ...
# 7849                   nagaland  2018        4  797120             2071
# 7850                   nagaland  2018        4  798601             1972
# 7851                   nagaland  2018        4  797117             1752
# 7852                   nagaland  2018        4  797118             1604
# 7853                   nagaland  2018        4  797116             1410
#
# [7854 rows x 5 columns]

# %%
import sqlite3
import streamlit as st
import plotly.express as px
# Connect to the SQLite database
conn = sqlite3.connect("phonepe.db")

# Create a cursor object
cursor = conn.cursor()

# Define the year you want to retrieve (e.g., 2018)
desired_year = 2018

# Define the quarter you want to retrieve (e.g., 1)
desired_quarter = 1

# Execute the SQL query with both year and quarter conditions
cursor.execute("SELECT * FROM agg_transc WHERE year = ? AND Quarter = ?", (desired_year, desired_quarter))
# Fetch all the rows that match the query
result = cursor.fetchall()

##st.plotly_chart(px.scatter(df, x='Transaction_type', y='Transaction_amount', title='Plotly Scatter Plot from SQLite Data'))
# Print the result
for row in result:
    print(row)
# Close the database connection
conn.close()
# Out:
# (1, 'andaman-&-nicobar-islands', 2018, 1, 'Recharge & bill payments', 4200, 1845307.467365509)
# (1, 'andaman-&-nicobar-islands', 2018, 1, 'Peer-to-peer payments', 1871, 12138655.299749982)
# (1, 'andaman-&-nicobar-islands', 2018, 1, 'Merchant payments', 298, 452507.168646613)
# (1, 'andaman-&-nicobar-islands', 2018, 1, 'Financial Services', 33, 10601.419933464951)
# (1, 'andaman-&-nicobar-islands', 2018, 1, 'Others', 256, 184689.8662902223)
# (31, 'tamil-nadu', 2018, 1, 'Recharge & bill payments', 3308548, 646028338.3951533)
# (31, 'tamil-nadu', 2018, 1, 'Peer-to-peer payments', 2670613, 10031518934.085688)
# (31, 'tamil-nadu', 2018, 1, 'Merchant payments', 326510, 272002057.1736871)
# (31, 'tamil-nadu', 2018, 1, 'Financial Services', 115363, 31876073.74792233)
# (31, 'tamil-nadu', 2018, 1, 'Others', 305588, 280132294.11422664)
# (306, 'lakshadweep', 2018, 1, 'Peer-to-peer payments', 423, 1860278.2784597145)
# ...

# %%
import sqlite3
import json

# Connect to the SQLite database
conn = sqlite3.connect("phonepe.db")

# Create a cursor object
cursor = conn.cursor()

# Define the year you want to retrieve (e.g., 2018)
desired_year = 2018

# Execute the SQL query
cursor.execute("SELECT * FROM agg_transc WHERE year = ?", (desired_year,))

# Fetch all the rows that match the query
result = cursor.fetchall()

# Convert the result to a list of dictionaries
result_list = []
for row in result:
    record_dict = {
        "Column1": row[0],  # Replace "Column1" with your actual column names
        "Column2": row[1],  # Replace "Column2" with your actual column names
        "Column3": row[2]   # Replace "Column3" with your actual column names
        # Add more columns as needed
    }
    result_list.append(record_dict)

# Save the result as a JSON file
json_filename = 'output.json'
with open(json_filename, 'w') as json_file:
    json.dump(result_list, json_file, indent=4)

print(f"Data saved to {json_filename}")

# Close the database connection
conn.close()
# Out:
# Data saved to output.json

# %%
import plotly.express as px
import pandas as pd

# %%
df = pd.read_csv("Data_Map_Districts_Longitude_Latitude (1).csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/karthikeyank/Documents/phonepe/NEW..IPYNB Cell 13 line 1
# ----> <a href='vscode-notebook-cell:/Users/karthikeyank/Documents/phonepe/NEW..IPYNB#X15sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv("Data_Map_Districts_Longitude_Latitude (1).csv")
#
# ...

# %%
import sqlite3

# %%
import sqlite3
import pandas as pd
import streamlit as st

def tw():
    conn = sqlite3.connect("phonepe.db")
    desired_year = 2018
    desired_quarter = 1
    query = "SELECT * FROM agg_transc WHERE year = ? AND Quarter = ?"
    df = pd.read_sql_query(query, conn, params=(desired_year, desired_quarter))
    st.dataframe(df)
    return df

tw()
# Out:
# 2023-09-23 15:40:48.790
# ...
#   command:
#
#     streamlit run /Users/karthikeyank/Library/Python/3.9/lib/python/site-packages/ipykernel_launcher.py [ARGUMENTS]
#      Unnamed: 0                      State  Year  Quarter  \
# 0            90  andaman-&-nicobar-islands  2018        1
# 1            91  andaman-&-nicobar-islands  2018        1
# 2            92  andaman-&-nicobar-islands  2018        1
# 3            93  andaman-&-nicobar-islands  2018        1
# 4            94  andaman-&-nicobar-islands  2018        1
# ..          ...                        ...   ...      ...
# 174        3934                   nagaland  2018        1
# 175        3935                   nagaland  2018        1
# 176        3936                   nagaland  2018        1
# 177        3937                   nagaland  2018        1
# 178        3938                   nagaland  2018        1
#
#              Transaction_type  Transaction_count  Transaction_amount
# ...

# %%
import json

# %%
import json
india_state=json.load(open("/Users/karthikeyank/Documents/phonepe/archive (5)/india_state.geojson",'r'))
india_state['features'][30]
# Out:
# {'type': 'Feature',
#  'properties': {'ID_0': 105,
#   'ISO': 'IND',
#   'NAME_0': 'India',
#   'ID_1': 31,
#   'NAME_1': 'Tamil Nadu',
#   'NL_NAME_1': None,
#   'VARNAME_1': 'Madras|Tamilnad',
#   'TYPE_1': 'State',
#   'ENGTYPE_1': 'State'},
#  'geometry': {'type': 'MultiPolygon',
#   'coordinates': [[[[77.55596160888678, 8.079030990600813],
#      [77.55596160888678, 8.078750610351847],
#      [77.55625152587919, 8.078750610351847],
#      [77.55625152587919, 8.07847118377697],
#      [77.55652618408203, 8.078473091125545],
#      [77.55652618408203, 8.077361106872786],
#      [77.55625152587919, 8.077361106872786],
#      [77.55625152587919, 8.077082633972225],
#      [77.5559692382813, 8.077082633972225],
#      [77.5559692382813, 8.076805114746321],
#      [77.55513763427734, 8.076805114746321],
#      [77.55513763427734, 8.076525688171444],
#      [77.55458068847673, 8.076525688171444],
#      [77.55458068847673, 8.076805114746321],
# ...

# %%
import sqlite3

# Connect to the SQLite database
conn = sqlite3.connect('phonepe.db')
cursor = conn.cursor()

# Replace 'your_table' with the name of your table
table_name = 'agg_transc'

# Execute the PRAGMA statement to get column information
cursor.execute(f"PRAGMA table_info({table_name})")

# Fetch all the rows (each row represents a column)
columns = cursor.fetchall()

# Extract and print the column names
column_names = [column[1] for column in columns]
print(column_names)

# Close the database connection
conn.close()
# Out:
# ['id', 'State', 'Year', 'Quarter', 'Transaction_type', 'Transaction_count', 'Transaction_amount']

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("phonepe.db")

# Execute the ALTER TABLE statement to rename the column with a unique name
alter_query = """
    ALTER TABLE agg_transc
    RENAME COLUMN Sid TO Transaction_type;
"""
conn.execute(alter_query)

# Now, you can retrieve data from the table using a SELECT query
query = "SELECT * FROM agg_transc;"
df = pd.read_sql_query(query, conn)

# Close the database connection
conn.close()

# Now, 'df' will contain the data from the 'agg_transc' table with the renamed column
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /Users/karthikeyank/Documents/phonepe/NEW..IPYNB Cell 19 line 1
#       <a href='vscode-notebook-cell:/Users/karthikeyank/Documents/phonepe/NEW..IPYNB#X26sZmlsZQ%3D%3D?line=5'>6</a> # Execute the ALTER TABLE statement to rename the column with a unique name
#       <a href='vscode-notebook-cell:/Users/karthikeyank/Documents/phonepe/NEW..IPYNB#X26sZmlsZQ%3D%3D?line=6'>7</a> alter_query = """
#       <a href='vscode-notebook-cell:/Users/karthikeyank/Documents/phonepe/NEW..IPYNB#X26sZmlsZQ%3D%3D?line=7'>8</a>     ALTER TABLE agg_transc
#       <a href='vscode-notebook-cell:/Users/karthikeyank/Documents/phonepe/NEW..IPYNB#X26sZmlsZQ%3D%3D?line=8'>9</a>     RENAME COLUMN Sid TO Transaction_type;
#      <a href='vscode-notebook-cell:/Users/karthikeyank/Documents/phonepe/NEW..IPYNB#X26sZmlsZQ%3D%3D?line=9'>10</a> """
# ...

# %%
import sqlite3

# Connect to the SQLite database
conn = sqlite3.connect('phonepe.db')
cursor = conn.cursor()

# Replace 'your_table' with the name of your table
table_name = 'agg_transc'

# Execute the ALTER TABLE statement to rename the column
cursor.execute(f"""
UPDATE agg_transc
SET ID = 31
WHERE state = 'tamil-nadu';
""")

# Commit the changes to the database
conn.commit()

# Close the database connection
conn.close()

# %%
import sqlite3
import pandas as pd
import folium
import plotly.express as px


conn=sqlite3.connect("phonepe.db")
query="SELECT * FROM agg_transc"
df=pd.read_sql_query(query,conn)
df
# Out:
#         id                      State  Year  Quarter  \
# 0        1  andaman-&-nicobar-islands  2022        1
# 1        1  andaman-&-nicobar-islands  2022        1
# 2        1  andaman-&-nicobar-islands  2022        1
# 3        1  andaman-&-nicobar-islands  2022        1
# 4        1  andaman-&-nicobar-islands  2022        1
# ...    ...                        ...   ...      ...
# 3949  3949                   nagaland  2018        4
# 3950  3950                   nagaland  2018        4
# 3951  3951                   nagaland  2018        4
# 3952  3952                   nagaland  2018        4
# 3953  3953                   nagaland  2018        4
#
#                            Sid  Transaction_count  Transaction_amount
# 0        Peer-to-peer payments             342649        1.682329e+09
# 1            Merchant payments             284298        3.700916e+08
# 2     Recharge & bill payments             163401        7.130013e+07
# ...

# %%
    def three():
        conn= sqlite3.connect("Youtube.db")
        query ="SELECT channel_title,title,SUM(view_count) as total_view FROM Youtube GROUP BY channel_title,title ORDER BY view_count DESC LIMIT 10;"
        df=pd.read_sql_query(query, conn)
        return df

# %%
def ii():
    conn=sqlite3.connect("phonepe.db")
    query="SELECT * FROM agg_transc "
    df=pd.read_sql_query(query,conn)
    return df
ii()
# Out:
#         id                      State  Year  Quarter  \
# 0        1  andaman-&-nicobar-islands  2022        1
# 1        1  andaman-&-nicobar-islands  2022        1
# 2        1  andaman-&-nicobar-islands  2022        1
# 3        1  andaman-&-nicobar-islands  2022        1
# 4        1  andaman-&-nicobar-islands  2022        1
# ...    ...                        ...   ...      ...
# 3949  3949                   nagaland  2018        4
# 3950  3950                   nagaland  2018        4
# 3951  3951                   nagaland  2018        4
# 3952  3952                   nagaland  2018        4
# 3953  3953                   nagaland  2018        4
#
#               Transaction_type  Transaction_count  Transaction_amount
# 0        Peer-to-peer payments             342649        1.682329e+09
# 1            Merchant payments             284298        3.700916e+08
# 2     Recharge & bill payments             163401        7.130013e+07
# ...

# %%
import sqlite3
import pandas as pd

# %%
def ii():
    conn=sqlite3.connect("phonepe.db")
    query="SELECT id,State,Year,Quarter,Transaction_amount FROM agg_transc GROUP BY id ORDER BY Transaction_amount DESC LIMIT 10" 
    df=pd.read_sql_query(query,conn)
    return df
ii()
# Out:
#      id           State  Year  Quarter  Transaction_amount
# 0   340       telangana  2022        4        2.393380e+12
# 1   335       telangana  2022        3        2.170173e+12
# 2   350       telangana  2023        2        2.155918e+12
# 3  1560       karnataka  2023        2        2.131662e+12
# 4  2220  andhra-pradesh  2023        2        2.067288e+12
# 5  1780     maharashtra  2023        2        1.923753e+12
# 6  1555       karnataka  2023        1        1.908849e+12
# 7   345       telangana  2023        1        1.898814e+12
# 8  2215  andhra-pradesh  2023        1        1.857818e+12
# 9  1775     maharashtra  2023        1        1.752753e+12

# %%
import sqlite3

# Connect to the SQLite database
conn = sqlite3.connect('phonepe.db')
cursor = conn.cursor()

# Replace 'your_table' with the name of your table
table_name = 'map_trans'

# Execute the PRAGMA statement to get column information
cursor.execute(f"PRAGMA table_info({table_name})")

# Fetch all the rows (each row represents a column)
columns = cursor.fetchall()

# Extract and print the column names
column_names = [column[1] for column in columns]
print(column_names)

# Close the database connection
conn.close()
# Out:
# ['State', 'Year', 'Quarter', 'District', 'Count', 'Amount']

# %%
import pandas as pd
import sqlite3

# %%
def ii():
    conn=sqlite3.connect("phonepe.db")
    query="SELECT Year,Quarter,District,Count,Amount FROM map_trans GROUP BY District ORDER BY Amount DESC LIMIT 10" 
    df=pd.read_sql_query(query,conn)
    return df
ii()
# Out:
#    Year  Quarter                     District      Count        Amount
# 0  2022        1     bengaluru urban district  648380838  8.379388e+11
# 1  2022        1           hyderabad district  372711414  6.615125e+11
# 2  2022        1                pune district  424149132  5.084751e+11
# 3  2022        1              jaipur district  262950613  4.345079e+11
# 4  2022        1              bhopal district  159892411  2.210968e+11
# 5  2022        1          rangareddy district  127675017  2.166099e+11
# 6  2022        1             central district  128309915  1.980726e+11
# 7  2022        1  medchal malkajgiri district  110893187  1.851683e+11
# 8  2022        1               patna district   91217400  1.707390e+11
# 9  2022        1       visakhapatnam district   88233362  1.701204e+11

# %%
import sqlite3

# Connect to the SQLite database
conn = sqlite3.connect('phonepe.db')
cursor = conn.cursor()

# Execute the UPDATE statement to change 'lakshadweep' to 'lk' in the 'state' column
cursor.execute("""
UPDATE agg_transc
SET state = 'Andaman and Nicobar'
WHERE state = 'Andaman and nicobar';
""")

# Commit the changes to the database
conn.commit()

# Close the database connection
conn.close()

# %%
import sqlite3
import pandas as pd
import folium
import plotly.express as px


conn=sqlite3.connect("phonepe.db")
query="SELECT * FROM agg_transc"
df=pd.read_sql_query(query,conn)
df
# Out:
#         id                State  Year  Quarter          Transaction_type  \
# 0        1  Andaman and Nicobar  2022        1     Peer-to-peer payments
# 1        1  Andaman and Nicobar  2022        1         Merchant payments
# 2        1  Andaman and Nicobar  2022        1  Recharge & bill payments
# 3        1  Andaman and Nicobar  2022        1        Financial Services
# 4        1  Andaman and Nicobar  2022        1                    Others
# ...    ...                  ...   ...      ...                       ...
# 3949  3949             nagaland  2018        4  Recharge & bill payments
# 3950  3950             nagaland  2018        4     Peer-to-peer payments
# 3951  3951             nagaland  2018        4         Merchant payments
# 3952  3952             nagaland  2018        4        Financial Services
# 3953  3953             nagaland  2018        4                    Others
#
#       Transaction_count  Transaction_amount
# 0                342649        1.682329e+09
# ...

# %%
import json 
india_state=json.load(open("/Users/karthikeyank/Documents/phonepe/archive (8)/state/india_telengana.geojson"))

# %%
india_state['features'][1]
# Out:
# {'type': 'Feature',
#  'properties': {'ID_0': 105,
#   'ISO': 'IND',
#   'NAME_0': 'India',
#   'ID_1': 36,
#   'NAME_1': 'Telangana'},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[77.50945281982428, 15.920860290527287],
#     [77.51457977294928, 15.943429946899357],
#     [77.51589965820312, 15.957461357116756],
#     [77.51487731933588, 15.963151931762752],
#     [77.50901031494158, 15.967440605163688],
#     [77.50551605224638, 15.972668647766056],
#     [77.50549316406278, 15.978761672973633],
#     [77.50839996337885, 15.995829582214412],
#     [77.51010894775385, 16.002250671386776],
#     [77.50168609619169, 16.005540847778377],
#     [77.50028228759771, 16.011350631713924],
#     [77.49857330322271, 16.013891220092717],
#     [77.49881744384794, 16.01716041564947],
#     [77.49207305908209, 16.02556991577154],
#     [77.49072265625, 16.03063011169445],
#     [77.49566650390642, 16.0477104187014],
#     [77.49447631835932, 16.049779891967773],
# ...

# %%
import sqlite3
import pandas as pd
import folium
import plotly.express as px


conn=sqlite3.connect("phonepe.db")
query="SELECT * FROM agg_transc"
df=pd.read_sql_query(query,conn)
df.head()
# Out:
#    id                State  Year  Quarter          Transaction_type  \
# 0   1  Andaman and nicobar  2022        1     Peer-to-peer payments
# 1   1  Andaman and nicobar  2022        1         Merchant payments
# 2   1  Andaman and nicobar  2022        1  Recharge & bill payments
# 3   1  Andaman and nicobar  2022        1        Financial Services
# 4   1  Andaman and nicobar  2022        1                    Others
#
#    Transaction_count  Transaction_amount
# 0             342649        1.682329e+09
# 1             284298        3.700916e+08
# 2             163401        7.130013e+07
# 3               1757        2.869682e+06
# 4               2643        2.440322e+06
